# %%
import pandas as pd
duplicateobservations=pd.read_csv('duplicateobservations.csv')
duplicateobservations
# Out:
#            Date            Market            Category   Commodity        Unit  \
# 0         #date  #loc+market+name          #item+type  #item+name  #item+unit
# 1    12/15/2021           Nairobi  cereals and tubers       Maize          KG
# 2    12/15/2021           Garissa  cereals and tubers       Maize          KG
# 3    12/15/2021            Kakuma  cereals and tubers       Maize          KG
# 4    12/15/2021         Mogadishu  cereals and tubers       Maize          KG
# ..          ...               ...                 ...         ...         ...
# 981         NaN               NaN                 NaN         NaN         NaN
# 982         NaN               NaN                 NaN         NaN         NaN
# 983         NaN               NaN                 NaN         NaN         NaN
# 984         NaN               NaN                 NaN         NaN         NaN
# 985         NaN               NaN                 NaN         NaN         NaN
#
# ...

# %%
duplicateobservations.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 981     True
# 982     True
# 983     True
# 984     True
# 985     True
# Length: 986, dtype: bool

# %%
duplicateobservations.drop_duplicates(inplace = True)
duplicateobservations
# Out:
#                    Date            Market            Category   Commodity  \
# 0                 #date  #loc+market+name          #item+type  #item+name
# 1            12/15/2021           Nairobi  cereals and tubers       Maize
# 2            12/15/2021           Garissa  cereals and tubers       Maize
# 3            12/15/2021            Kakuma  cereals and tubers       Maize
# 4            12/15/2021         Mogadishu  cereals and tubers       Maize
# 5            12/15/2021           Baringo  cereals and tubers       Maize
# 6            12/15/2021             Wajir  cereals and tubers       Maize
# 7            12/15/2021            Kisumu  cereals and tubers       Maize
# 8            12/15/2021            Nakuru  cereals and tubers       Maize
# 9            12/15/2021           Eldoret  cereals and tubers       Maize
# 10           12/15/2021         Kalobeyei  cereals and tubers       Maize
# 11            1/15/2022           Nairobi  cereals and tubers       Maize
# ...

# %%
duplicateobservations.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 17    False
# 18    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# dtype: bool
