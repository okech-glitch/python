# %%
import pandas as pd
supermarket=pd.read_csv('supermarket.csv')
supermarket
# Out:
#     ProductID    ProductName  Quantity  Price     LastUpdated
# 0           1           Milk        20   65.0  7/5/2025 15:00
# 1           2          Bread        30   60.0  7/5/2025 14:30
# 2           3          Sugar        15  120.0  7/4/2025 10:00
# 3           4          Flour        25  150.0  7/3/2025 16:45
# 4           5           Rice        40    NaN   7/5/2025 9:15
# ..        ...            ...       ...    ...             ...
# 58         56     Cling Film        15   90.0   7/4/2025 9:00
# 59         57  Aluminum Foil        12  100.0  7/5/2025 12:00
# 60         58     Trash Bags        25   60.0  7/3/2025 14:45
# 61         59     Toothpicks        40   30.0  7/4/2025 10:30
# 62         60   Strawberries         8  250.0  7/5/2025 13:00
#
# [63 rows x 5 columns]

# %%
#check for null values
supermarket.isna()
# Out:
#     ProductID  ProductName  Quantity  Price  LastUpdated
# 0       False        False     False  False        False
# 1       False        False     False  False        False
# 2       False        False     False  False        False
# 3       False        False     False  False        False
# 4       False        False     False   True        False
# ..        ...          ...       ...    ...          ...
# 58      False        False     False  False        False
# 59      False        False     False  False        False
# 60      False        False     False  False        False
# 61      False        False     False  False        False
# 62      False        False     False  False        False
#
# [63 rows x 5 columns]

# %%
#drop null values
supermarket.dropna()
# Out:
#     ProductID         ProductName  Quantity  Price     LastUpdated
# 0           1                Milk        20   65.0  7/5/2025 15:00
# 1           2               Bread        30   60.0  7/5/2025 14:30
# 2           3               Sugar        15  120.0  7/4/2025 10:00
# 3           4               Flour        25  150.0  7/3/2025 16:45
# 5           5                Rice        40   80.0   7/5/2025 9:15
# 6           6         Cooking Oil        18  200.0  7/2/2025 12:00
# 7           7          Tea Leaves        22   90.0  7/5/2025 11:30
# 8           8              Coffee        10  250.0   7/4/2025 8:00
# 10         10               Beans        28  110.0  7/5/2025 13:00
# 11         11            Soap Bar        50   40.0  7/4/2025 15:10
# 13         12          Toothpaste        15  120.0   7/3/2025 9:45
# 15         14        Toilet Paper        60   25.0  7/2/2025 11:30
# 16         15             Shampoo        12  150.0  7/4/2025 12:15
# ...

# %%
#check for duplicates
supermarket.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
supermarket.drop_duplicates()
# Out:
#     ProductID    ProductName  Quantity  Price     LastUpdated
# 0           1           Milk        20   65.0  7/5/2025 15:00
# 1           2          Bread        30   60.0  7/5/2025 14:30
# 2           3          Sugar        15  120.0  7/4/2025 10:00
# 3           4          Flour        25  150.0  7/3/2025 16:45
# 4           5           Rice        40    NaN   7/5/2025 9:15
# ..        ...            ...       ...    ...             ...
# 58         56     Cling Film        15   90.0   7/4/2025 9:00
# 59         57  Aluminum Foil        12  100.0  7/5/2025 12:00
# 60         58     Trash Bags        25   60.0  7/3/2025 14:45
# 61         59     Toothpicks        40   30.0  7/4/2025 10:30
# 62         60   Strawberries         8  250.0  7/5/2025 13:00
#
# [63 rows x 5 columns]

# %%
#normalize Quantity and Price
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
supermarket[['Quantity','Price']]=scaler.fit_transform(supermarket[['Quantity','Price']])
supermarket.head()
# Out:
#    ProductID ProductName  Quantity     Price     LastUpdated
# 0          1        Milk  0.272727  0.203390  7/5/2025 15:00
# 1          2       Bread  0.454545  0.186441  7/5/2025 14:30
# 2          3       Sugar  0.181818  0.389831  7/4/2025 10:00
# 3          4       Flour  0.363636  0.491525  7/3/2025 16:45
# 4          5        Rice  0.636364       NaN   7/5/2025 9:15

# %%
#Starndadization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
supermarket[['Quantity','Price']]=scaler.fit_transform(supermarket[['Quantity','Price']])
supermarket
# Out:
#     ProductID    ProductName  Quantity     Price     LastUpdated
# 0           1           Milk -0.335988 -0.560878  7/5/2025 15:00
# 1           2          Bread  0.391409 -0.634608  7/5/2025 14:30
# 2           3          Sugar -0.699687  0.250157  7/4/2025 10:00
# 3           4          Flour  0.027710  0.692539  7/3/2025 16:45
# 4           5           Rice  1.118806       NaN   7/5/2025 9:15
# ..        ...            ...       ...       ...             ...
# 58         56     Cling Film -0.699687 -0.192226   7/4/2025 9:00
# 59         57  Aluminum Foil -0.917906 -0.044765  7/5/2025 12:00
# 60         58     Trash Bags  0.027710 -0.634608  7/3/2025 14:45
# 61         59     Toothpicks  1.118806 -1.076991  7/4/2025 10:30
# 62         60   Strawberries -1.208865  2.167148  7/5/2025 13:00
#
# [63 rows x 5 columns]
